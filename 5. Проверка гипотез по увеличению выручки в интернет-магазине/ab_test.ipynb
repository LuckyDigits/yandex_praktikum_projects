# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка их к анализу</a></span></li><li><span><a href="#Приоритизация-гипотез" data-toc-modified-id="Приоритизация-гипотез-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Приоритизация гипотез</a></span><ul class="toc-item"><li><span><a href="#Расчёт-ICE-для-приоритизации-гипотез" data-toc-modified-id="Расчёт-ICE-для-приоритизации-гипотез-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Расчёт ICE для приоритизации гипотез</a></span></li><li><span><a href="#Расчёт-RICE-для-приоритизации-гипотез" data-toc-modified-id="Расчёт-RICE-для-приоритизации-гипотез-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Расчёт RICE для приоритизации гипотез</a></span></li></ul></li><li><span><a href="#Анализ-результатов-A/B-теста" data-toc-modified-id="Анализ-результатов-A/B-теста-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ результатов A/B-теста</a></span><ul class="toc-item"><li><span><a href="#Анализ-кумулятивных-метрик" data-toc-modified-id="Анализ-кумулятивных-метрик-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ кумулятивных метрик</a></span><ul class="toc-item"><li><span><a href="#Кумулятивная-выручка-по-группам" data-toc-modified-id="Кумулятивная-выручка-по-группам-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Кумулятивная выручка по группам</a></span></li><li><span><a href="#Кумулятивный-средний-чек-по-группам" data-toc-modified-id="Кумулятивный-средний-чек-по-группам-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Кумулятивный средний чек по группам</a></span></li><li><span><a href="#Относительное-изменение-кумулятивного-среднего-чека-группы-B-к-группе-A" data-toc-modified-id="Относительное-изменение-кумулятивного-среднего-чека-группы-B-к-группе-A-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Относительное изменение кумулятивного среднего чека группы B к группе A</a></span></li><li><span><a href="#Кумулятивное-среднее-количество-заказов-на-посетителя-по-группам" data-toc-modified-id="Кумулятивное-среднее-количество-заказов-на-посетителя-по-группам-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Кумулятивное среднее количество заказов на посетителя по группам</a></span></li><li><span><a href="#Относительное-изменение-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A" data-toc-modified-id="Относительное-изменение-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Относительное изменение кумулятивного среднего количества заказов на посетителя группы B к группе A</a></span></li></ul></li><li><span><a href="#Анализ-выбросов-и-всплесков" data-toc-modified-id="Анализ-выбросов-и-всплесков-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ выбросов и всплесков</a></span><ul class="toc-item"><li><span><a href="#Анализ-аномалий-в-количестве-заказов-по-пользователям" data-toc-modified-id="Анализ-аномалий-в-количестве-заказов-по-пользователям-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Анализ аномалий в количестве заказов по пользователям</a></span></li><li><span><a href="#Анализ-аномалий-в-стоимости-заказов" data-toc-modified-id="Анализ-аномалий-в-стоимости-заказов-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Анализ аномалий в стоимости заказов</a></span></li></ul></li><li><span><a href="#Статистический-анализ-по-«сырым»-данным" data-toc-modified-id="Статистический-анализ-по-«сырым»-данным-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Статистический анализ по «сырым» данным</a></span></li><li><span><a href="#Статистический-анализ-по--«очищенным»-данным" data-toc-modified-id="Статистический-анализ-по--«очищенным»-данным-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Статистический анализ по  «очищенным» данным</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации" data-toc-modified-id="Выводы-и-рекомендации-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы и рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Проверка гипотез по увеличению выручки в интернет-магазине

# %% [markdown]
# В нашем распоряжении данные крупного интернет-магазина. Вместе с отделом маркетинга был подготовлен список гипотез для увеличения выручки. Необходимо приоритизировать гипотезы, запустить A/B-тест, проанализировать результаты и сделать выводы об успешности тестируемого изменения.
#
# Для анализа результатов A/B-теста будем использовать следующие метрики: кумулятивная выручка, кумулятивный средний чек и кумулятивное среднее количество заказов на посетителя. Также, воспользуемся критерием Манна-Уитни для сравнения среднего количества заказов на посетителя и среднего чека заказа между группами.

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
pd.options.display.max_colwidth = 110

# %%
hypothesis = pd.read_csv('/datasets/hypothesis.csv')
orders = pd.read_csv('/datasets/orders.csv')
visitors = pd.read_csv('/datasets/visitors.csv')

# %% [markdown]
# Выведем несколько строк из каждого датасета.

# %%
hypothesis
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %%
orders.head(10)
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
# 5      182168103   935554773  2019-08-15     2210     B
# 6      398296753  2900797465  2019-08-15     1860     B
# 7     2626614568    78758296  2019-08-15     1044     A
# 8     1576988021   295230930  2019-08-15    13710     A
# 9     1506739906  1882260405  2019-08-15     1855     B

# %%
visitors.head(10)
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756
# 5  2019-08-06     A       667
# 6  2019-08-07     A       644
# 7  2019-08-08     A       610
# 8  2019-08-09     A       617
# 9  2019-08-10     A       406

# %% [markdown]
# Посмотрим общую информацию о датасетах.

# %%
def data_info(data):
    print(data.info())
    print('')
    print(data.describe())
    print('')
    print('Количество пропусков в датасете:')
    print(data.isna().sum())
    print('')
    print('Количество явных дубликатов в датасете:')
    print(data.duplicated().sum())

# %%
data_info(hypothesis)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes
# None
#
#            Reach     Impact  Confidence    Efforts
# count   9.000000   9.000000    9.000000   9.000000
# mean    4.777778   4.777778    5.555556   4.888889
# std     3.153481   3.192874    3.045944   2.803767
# min     1.000000   1.000000    1.000000   1.000000
# 25%     3.000000   3.000000    3.000000   3.000000
# 50%     3.000000   3.000000    7.000000   5.000000
# 75%     8.000000   7.000000    8.000000   6.000000
# max    10.000000  10.000000    9.000000  10.000000
#
# Количество пропусков в датасете:
# Hypothesis    0
# ...

# %%
data_info(orders)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
# None
#
#        transactionId     visitorId       revenue
# count   1.197000e+03  1.197000e+03  1.197000e+03
# mean    2.155621e+09  2.165960e+09  8.348006e+03
# std     1.229085e+09  1.236014e+09  3.919113e+04
# min     1.062393e+06  5.114589e+06  5.000000e+01
# 25%     1.166776e+09  1.111826e+09  1.220000e+03
# 50%     2.145194e+09  2.217985e+09  2.978000e+03
# 75%     3.237740e+09  3.177606e+09  8.290000e+03
# max     4.293856e+09  4.283872e+09  1.294500e+06
#
# Количество пропусков в датасете:
# ...

# %%
data_info(visitors)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
# None
#
#          visitors
# count   62.000000
# mean   607.290323
# std    114.400560
# min    361.000000
# 25%    534.000000
# 50%    624.500000
# 75%    710.500000
# max    770.000000
#
# Количество пропусков в датасете:
# date        0
# group       0
# visitors    0
# dtype: int64
#
# Количество явных дубликатов в датасете:
# 0

# %% [markdown]
# Ни в одном из исходных датасетов не обнаружены пропуски, явные дубликаты. Переименуем некоторые столбцы в соответствии с snake case.

# %%
orders = orders.rename(columns={'transactionId': 'transaction_id', 'visitorId': 'visitor_id'})

# %% [markdown]
# Также, приведём столбцы с датой к типу datetime.

# %%
orders['date'] = pd.to_datetime(orders['date']).dt.date
visitors['date'] = pd.to_datetime(visitors['date']).dt.date

# %% [markdown]
# ## Приоритизация гипотез

# %% [markdown]
# Для приоритизации гипотез будем использовать методы ICE и RICE.
#
# **ICE** (влияние, уверенность, усилия):
#
#                                 ICE score = (Impact x Confidence) / Efforts
#
# **RICE** (влияние, уверенность, усилия, охват):
#
#                                 RICE score = (Reach x Impact x Confidence) / Efforts
#
# Фреймворк RICE состоит из четырёх компонент:
# - Reach — скольких пользователей затронет изменение, которое вы хотите внести;
# - Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# - Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# - Efforts — сколько стоит протестировать эту гипотезу.

# %% [markdown]
# ### Расчёт ICE для приоритизации гипотез

# %%
hypothesis['ICE'] = round(hypothesis['Impact'] * hypothesis['Confidence'] / hypothesis['Efforts'], 2)
hypothesis[['Hypothesis', 'ICE']].sort_values(by='ICE', ascending=False)
# Out:
#                                                                                                      Hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Топ-3 наиболее приоритетные гипотезы:
# 1) 8 — Запустить акцию, дающую скидку на товар в день рождения;
# 2) 0 — Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей;
# 3) 7 — Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
#
# Меньше всего набрала гипотеза под номером 4 — изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей.

# %% [markdown]
# ### Расчёт RICE для приоритизации гипотез

# %%
hypothesis['RICE'] = hypothesis['Reach'] * hypothesis['Impact'] * hypothesis['Confidence'] / hypothesis['Efforts']
hypothesis[['Hypothesis', 'RICE']].sort_values(by='RICE', ascending=False)
# Out:
#                                                                                                      Hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Топ-3 гипотезы по количеству баллов:
# 1) 7 — Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок;
# 2) 2 — Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа;
# 3) 1 — Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
#
# Меньше всего баллов также набрала гипотеза под номером 4 — изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей.

# %% [markdown]
# При применении RICE вместо ICE приоритизация гипотез менялась в зависимости от оценки параметра Reach (охват пользователей) — при прочих равных, чем выше был оценён этот параметр у гипотезы, тем более высокую оценку она получила в итоге.

# %% [markdown]
# ## Анализ результатов A/B-теста

# %% [markdown]
# Прежде чем приступать к анализу результатов A/B-теста убедимся, что пользователи оставались в одной и той же группе от начала и до конца теста. Подсчитаем количество пользователей, оказавшихся в более чем 1 группе.

# %%
orders_dubs = orders.pivot_table(index='visitor_id', values='group', aggfunc='nunique').reset_index()
orders_dubs.query('group > 1')['group'].count()
# Out:
# 58

# %% [markdown]
# В исходных данных оказалось 58 таких пользователей. Если пользователь видит разные версии исследуемой страницы в ходе одного исследования, неизвестно, какая именно повлияла на его решения. Значит, и результаты такого теста нельзя интерпретировать однозначно. Исключим данных пользователей из дальнейшего анализа.

# %%
dubs = list(orders_dubs.query('group != 1')['visitor_id'])

# %%
orders_clean = orders.query('visitor_id not in @dubs')

# %% [markdown]
# Также, проверим, какое количество пользователей в попало в каждую из групп.

# %%
print('Количество пользователей в группе "А":', orders_clean[orders_clean['group']=='A']['visitor_id'].nunique())
print('Количество пользователей в группе "B":', orders_clean[orders_clean['group']=='B']['visitor_id'].nunique())
# Out:
# Количество пользователей в группе "А": 445
# Количество пользователей в группе "B": 528

# %% [markdown]
# Количество пользователей в группах различается более чем на 1%.

# %% [markdown]
# ### Анализ кумулятивных метрик

# %% [markdown]
# #### Кумулятивная выручка по группам

# %% [markdown]
# Построим графики кумулятивной выручки по дням и группам A/B-тестирования.

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = orders_clean[['date','group']].drop_duplicates()

# получаем агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply(lambda x: orders_clean[np.logical_and(
                                    orders_clean['date'] <= x['date'],
                                    orders_clean['group'] == x['group'])]
                                    .agg({'date': 'max',
                                           'group': 'max',
                                           'transaction_id': 'nunique',
                                           'visitor_id': 'nunique',
                                           'revenue': 'sum'}), axis=1).sort_values(by=['date', 'group'])

# получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'],
                                                                         visitors['group'] == x['group'])]
                                       .agg({'date': 'max', 'group': 'max', 'visitors': 'sum'}), axis=1).sort_values(by=['date', 'group'])

# объединяем кумулятивные данные в одной таблице
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

plt.figure(figsize=(14, 8))
plt.title('Изменение кумулятивной выручки по группам')
# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')
plt.legend() 
plt.xlabel("Дата")
plt.ylabel("Выручка")
# Out:
# Text(0, 0.5, 'Выручка')

# %% [markdown]
#  К концу теста кумулятивная выручка в группе B превышает кумулятивную выручку в группе A более чем в 1,5 раза.
#
# График выручки в группе B резко растёт в районе 19 августа. Это может сигнализировать о всплеске числа заказов, либо о появлении очень дорогих заказов в выборке.

# %% [markdown]
# #### Кумулятивный средний чек по группам

# %% [markdown]
# Построим графики среднего чека по группам — разделим кумулятивную выручку на кумулятивное число заказов.

# %%
plt.figure(figsize=(14, 8))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B') 
plt.title('Изменение кумулятивного среднего чека по группам')
plt.xlabel("Дата")
plt.ylabel("Средний чек")
plt.legend()

# %% [markdown]
# Кумулятивный средний чек группы B значительно превышает кумулятивный средний чек группы  A — на конец теста разница составила около 28%.
#
# Средний чек становится равномерным ближе к концу теста: установился для группы A и продолжает падать для группы B. Возможно, в группу B попали крупные заказы (резкий всплеск на графике).

# %% [markdown]
# #### Относительное изменение кумулятивного среднего чека группы B к группе A

# %% [markdown]
# Построим график относительного различия для среднего чека.

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.figure(figsize=(14, 8))
plt.title('Относительное изменение кумулятивного среднего чека группы B к группе A')
# cтроим отношение средних чеков
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel("Дата")
plt.ylabel("Разница между сегментами")
# Out:
# Text(0, 0.5, 'Разница между сегментами')

# %% [markdown]
# В нескольких точках график различия между сегментами резко скачет. Это ещё раз подтверждает, что в данных присутствуют необычно крупные заказы и выбросы.

# %% [markdown]
# #### Кумулятивное среднее количество заказов на посетителя по группам

# %% [markdown]
# Построим график кумулятивного среднего количества заказов на посетителя по группам.

# %%
# считаем кумулятивное количество заказов на посетителя
cumulativeData['conversion'] = cumulativeData['orders'] / cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# строим графики
plt.figure(figsize=(14, 8))
plt.title('Изменение кумулятивного среднего количества заказов на посетителя по группам')
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.xlabel("Дата")
plt.ylabel("Среднее количество заказов на пользователя")
plt.legend()

# %% [markdown]
# Графики обоих групп неравномерные. Кумулятивное количество заказов на посетителя группы B изначально отставало от группы A, но, начиная с 6 августа стало стабильно опережать её.

# %% [markdown]
# ####  Относительное изменение кумулятивного среднего количества заказов на посетителя группы B к группе A

# %% [markdown]
# Построим график относительного различия кумулятивного среднего количества заказов на посетителя группы B к группе A.

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']],
                                                                           left_on='date',
                                                                           right_on='date',
                                                                           how='left',
                                                                           suffixes=['A', 'B'])
plt.figure(figsize=(14, 8))
plt.title('Относительный прирост кумулятивного среднего количества заказов на посетителя группы B относительно группы A')
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/
         mergedCumulativeConversions['conversionA']-1)
plt.xlabel("Дата")
plt.ylabel("Разница между сегментами")
# Out:
# Text(0, 0.5, 'Разница между сегментами')

# %% [markdown]
# В самом начале теста группа B значительно проигрывала группе A, затем вырвалась вперёд и стабильно опережала её до конца теста.

# %% [markdown]
# ### Анализ выбросов и всплесков

# %% [markdown]
# #### Анализ аномалий в количестве заказов по пользователям

# %% [markdown]
# Построим точечный график количества заказов по пользователям.

# %%
ordersByUsers = orders_clean.groupby('visitor_id', as_index=False).agg({'transaction_id': 'nunique'})
ordersByUsers.columns = ['user_id', 'orders']

# %%
x_values = pd.Series(range(0,len(ordersByUsers)))
plt.figure(figsize=(14, 8))
plt.title('Диаграмма рассеяния количества заказов')
plt.scatter(x_values, ordersByUsers['orders']) 
plt.xlabel("Порядковый номер пользователя")
plt.ylabel("Количество заказов")
# Out:
# Text(0, 0.5, 'Количество заказов')

# %%
ordersByUsers.query('orders > 1')['user_id'].count()
# Out:
# 36

# %% [markdown]
# Больше 1 заказа совершили только 36 пользователей: 29 из них — 2 заказа, 7 — 3 заказа.

# %% [markdown]
# Посчитаем 95-й и 99-й перцентили, чтобы убедиться, что граница аномальности выбрана верно.

# %%
np.percentile(ordersByUsers['orders'], [95, 99])
# Out:
# array([1., 2.])

# %% [markdown]
# Менее 5% пользователей совершили больше 1 заказа, менее 1% — больше 2. Можно исключить пользователей с более чем 1 заказом без больших потерь для данных.

# %% [markdown]
# #### Анализ аномалий в стоимости заказов

# %% [markdown]
# Построим точечный график стоимости заказов по пользователям.

# %%
x_values = pd.Series(range(0, len(orders_clean['revenue'])))
plt.figure(figsize=(14, 8))
plt.title('Диаграмма рассеяния стоимости заказов')
plt.scatter(x_values, orders_clean['revenue'])
plt.xlabel("Порядковый номер заказа")
plt.ylabel("Стоимость заказа")
# Out:
# Text(0, 0.5, 'Стоимость заказа')

# %% [markdown]
# На графике видны отдельные выбросы, но не очень понятно где провести границу аномальности. Ситуацию должны прояснить 95-й и 99-й перцентили стоимости заказов.

# %%
np.percentile(orders_clean['revenue'], [95, 99])
# Out:
# array([26785., 53904.])

# %% [markdown]
# Не более 5% заказов дороже 26 785 рублей и не более 1% дороже 53 904 рублей.

# %%
orders_clean.query('revenue > 27000')['transaction_id'].count()
# Out:
# 51

# %% [markdown]
# Аномальными будем считать заказы более 27 000 рублей, их всего 51 шт.

# %% [markdown]
# ### Статистический анализ по «сырым» данным

# %% [markdown]
# Посчитаем статистическую значимость различий в среднем числе заказов на пользователя и среднем чеке между группами по «сырым» данным — без удаления аномальных пользователей. Подготовим данные.

# %%
# получаем данные о посещениях группы А по дням
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

# получаем агрегированные кумулятивные по дням данные о посещениях группы А 
visitorsACummulative = visitorsADaily.apply(lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']]
                                            .agg({'date': 'max', 'visitorsPerDateA': 'sum'}), axis=1)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

# получаем данные о посещениях группы B по дням
visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

# получаем агрегированные кумулятивные по дням данные о посещениях группы B 
visitorsBCummulative = visitorsBDaily.apply(lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']]
                                            .agg({'date': 'max', 'visitorsPerDateB': 'sum'}), axis=1)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

# получаем агрегированные данные о заказах группы А по дням
ordersADaily = (orders_clean[orders_clean['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'}))
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

# получаем агрегированные кумулятивные по дням данные о заказах группы A
ordersACummulative = ordersADaily.apply(lambda x: ordersADaily[ordersADaily['date'] <= x['date']]
                                        .agg({'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}), axis=1).sort_values(by=['date'])
ordersACummulative.columns = ['date', 'ordersCummulativeA', 'revenueCummulativeA']

# получаем агрегированные данные о заказах группы B по дням
ordersBDaily = (orders_clean[orders_clean['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'}))
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

# получаем агрегированные кумулятивные по дням данные о заказах группы B
ordersBCummulative = ordersBDaily.apply(lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']]
                                        .agg({'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}), axis=1).sort_values(by=['date'])
ordersBCummulative.columns = ['date', 'ordersCummulativeB', 'revenueCummulativeB']

# объединяем полученные таблицы в одну
data = (ordersADaily.merge(ordersBDaily, left_on='date', right_on='date', how='left')
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left'))

# %% [markdown]
# Создадим переменные `ordersByUsersA` и `ordersByUsersB` со столбцами `user_id`, `orders`. В них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов.

# %%
ordersByUsersA = (orders_clean[orders_clean['group'] == 'A']
                  .groupby('visitor_id', as_index=False)
                  .agg({'transaction_id': pd.Series.nunique}))
ordersByUsersA.columns = ['user_id', 'orders']

ordersByUsersB = (orders_clean[orders_clean['group'] == 'B']
                 .groupby('visitor_id', as_index=False)
                 .agg({'transaction_id': pd.Series.nunique}))
ordersByUsersB.columns = ['user_id', 'orders']

# %% [markdown]
# Объявим переменные `sampleA` и `sampleB`, в которых пользователям из разных групп будет соответствовать количество заказов. Тем, кто ничего не заказал, будут соответствовать нули.

# %%
sampleA = pd.concat([ordersByUsersA['orders'],
                    pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])),
                    name='orders')], axis=0)

sampleB = pd.concat([ordersByUsersB['orders'], 
                     pd.Series(0, index=np.arange(data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])),
                     name='orders')], axis=0)

# %% [markdown]
# Для оценки статистической значимости различий в среднем числе заказов между группами воспользуемся критерием Манна-Уитни, где:
# * Нулевая гипотеза — различий в среднем количестве заказов между группами нет;
# * Альтернативная — различия в среднем между группами есть.
#
# Также, выведем относительный прирост среднего числа заказов группы B.

# %%
print('P-value:', "{0:.5f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))
print('Относительный прирост среднего числа заказов группы B:', "{0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# P-value: 0.01102
# Относительный прирост среднего числа заказов группы B: 0.160

# %% [markdown]
# P-value меньше 0.05. Значит, нулевую гипотезу можно отвергнуть — различия в среднем между группами есть. Относительный выйгрыш группы B равен 16%.

# %% [markdown]
# Посчитаем статистическую значимость различий в среднем чеке заказа между группами:
# * Нулевая гипотеза — различий в среднем чеке между группами нет;
# * Альтернативная — различия в среднем между группами есть.

# %%
print('P-value:', '{0:.3f}'.format(stats.mannwhitneyu(orders_clean[orders_clean['group']=='A']['revenue'],
                                                       orders_clean[orders_clean['group']=='B']['revenue'])[1]))
print('Относительный прирост среднего чека группы B:', '{0:.3f}'.format(orders_clean[orders_clean['group']=='B']['revenue'].mean()/
                                                                        orders_clean[orders_clean['group']=='A']['revenue'].mean()-1))
# Out:
# P-value: 0.829
# Относительный прирост среднего чека группы B: 0.287

# %% [markdown]
# P-value значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет. При этом, средний чек группы B выше среднего чека группы A на 28,7%.

# %% [markdown]
# ### Статистический анализ по  «очищенным» данным

# %% [markdown]
# «Очистим» данные от аномалий. Аномальными будем считать пользователей с более чем 1 заказом и суммой заказа более 27 000 рублей.

# %%
usersWithManyOrders = pd.concat([ordersByUsersA[ordersByUsersA['orders'] > 1]['user_id'],
                                 ordersByUsersB[ordersByUsersB['orders'] > 1]['user_id']], axis=0)
usersWithExpensiveOrders = orders_clean[orders_clean['revenue'] > 27000]['visitor_id']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)

abnormalUsers.shape[0]
# Out:
# 86

# %% [markdown]
# Всего 86 аномальных пользователей.

# %% [markdown]
# Узнаем, как их действия повлияли на результаты теста. Посчитаем статистическую значимость различий в среднем количестве заказов между группами теста по «очищенным» данным.

# %%
sampleAFiltered = pd.concat([ordersByUsersA[np.logical_not(ordersByUsersA['user_id'].isin(abnormalUsers))]['orders'],
                            pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])),
                            name='orders')], axis=0)

sampleBFiltered = pd.concat([ordersByUsersB[np.logical_not(ordersByUsersB['user_id'].isin(abnormalUsers))]['orders'],
                            pd.Series(0, index=np.arange(data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])),
                            name='orders')], axis=0)

# %% [markdown]
# Применим статистический критерий Манна-Уитни к полученным выборкам.

# %%
print('P-value:', '{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('Относительный прирост среднего числа заказов группы B:', '{0:.3f}'.format(sampleBFiltered.mean()/
                                                                                 sampleAFiltered.mean()-1))
# Out:
# P-value: 0.016
# Относительный прирост среднего числа заказов группы B: 0.174

# %% [markdown]
# Результаты по «очищенным» данным отличаются от «сырых», но незначительно. Нулевая гипотеза здесь также отвергнута, так как средние по группам отличаются статистически значимо.

# %% [markdown]
# Посмотрим, изменились ли результаты по среднему чеку.

# %%
print('P-value:', '{0:.3f}'.format(stats.mannwhitneyu(orders_clean[np.logical_and(orders_clean['group'] == 'A',
                                                                    np.logical_not(orders_clean['visitor_id']
                                                                      .isin(abnormalUsers)))]['revenue'],
                                                       orders_clean[np.logical_and(orders_clean['group'] == 'B',
                                                                    np.logical_not(orders_clean['visitor_id']
                                                                      .isin(abnormalUsers)))]['revenue'])[1]))

print('Относительный прирост среднего чека группы B:', 
      "{0:.3f}".format(orders_clean[np.logical_and(orders_clean['group'] == 'B',
                                    np.logical_not(orders_clean['visitor_id']
                                                   .isin(abnormalUsers)))]['revenue'].mean()
                    / orders_clean[np.logical_and(orders_clean['group'] == 'A',
                                   np.logical_not(orders_clean['visitor_id'].isin(abnormalUsers)))]['revenue'].mean() - 1))
# Out:
# P-value: 0.727
# Относительный прирост среднего чека группы B: -0.034

# %% [markdown]
# P-value уменьшился, но незначительно. А разница между сегментами заметно изменилась — средний чек у группы B после удаления аномалий стал ниже чем у группы A.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1) Среднее число заказов на пользователя что по «сырым», что по «очищенным» данным статистически значимо отличаются между группами;
# 2) Средний чек между группами не отличается статистически значимо как по «сырым», так и по «очищенным» данным.

# %% [markdown]
# ## Выводы и рекомендации

# %% [markdown]
# На этапе анализа кумулятивных метрик обеих групп по результатам A/B-теста были сделаны следующие выводы:
# * к концу теста кумулятивная выручка в группе B превышает кумулятивную выручку в группе A более чем в 1,5 раза;
# * кумулятивный средний чек группы B значительно превышает кумулятивный средний чек группы A — на конец теста разница составила около 28%;
# * кумулятивное среднее количество заказов на посетителя группы B также значительно превышает аналогичную метрику группы A.
#
# Также, в ходе анализа результатов теста были обнаружены аномалии: пользователи с необычно большим количеством заказов, необычно большой стоимостью заказов.
#
# В ходе статистического анализа использовались как «сырые» (с аномалиями), так и «очищенные» (без аномалий) данные. В результате были сделаны следующие выводы:
# * среднее число заказов на пользователя что по «сырым», что по «очищенным» данным статистически значимо отличаются между группами;
# * средний чек между группами не отличается статистически значимо как по «сырым», так и по «очищенным» данным.
#
# Исходя из обнаруженных фактов, тест можно остановить и признать его успешным — даже несмотря на то, что средний чек между группами статистически значимо не отличается, среднее число заказов на пользователя в группе B превышает среднее число заказов на пользователя в группе A (относительный прирост среднего числа заказов группы B по  «очищенным» данным составил 17,4%).
#
# *Рекомендации*
#
# Необходимо проверить корректность механизма деления пользователей на группы, так как во время анализа данных обнаружены 58 пользователей попавших в обе группы.
