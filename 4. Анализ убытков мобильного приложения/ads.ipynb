# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка их к анализу</a></span></li><li><span><a href="#Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчёта и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Распределение-пользователей-по-странам" data-toc-modified-id="Распределение-пользователей-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение пользователей по странам</a></span></li><li><span><a href="#Распределение-пользователей-по-устройствам" data-toc-modified-id="Распределение-пользователей-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Распределение пользователей по устройствам</a></span></li><li><span><a href="#Распределение-пользователей-по-каналам-привлечения-пользователей" data-toc-modified-id="Распределение-пользователей-по-каналам-привлечения-пользователей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Распределение пользователей по каналам привлечения пользователей</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span></li><li><span><a href="#Окупаемость-рекламы" data-toc-modified-id="Окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span></li><li><span><a href="#Конверсия-и-удержание-пользователей" data-toc-modified-id="Конверсия-и-удержание-пользователей-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Конверсия и удержание пользователей</a></span><ul class="toc-item"><li><span><a href="#Конверсия-и-удержание-пользователей-в-общем" data-toc-modified-id="Конверсия-и-удержание-пользователей-в-общем-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Конверсия и удержание пользователей в общем</a></span></li><li><span><a href="#Конверсия-и-удержание-пользователей-с-разбивкой-по-странам" data-toc-modified-id="Конверсия-и-удержание-пользователей-с-разбивкой-по-странам-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Конверсия и удержание пользователей с разбивкой по странам</a></span></li><li><span><a href="#Конверсия-и-удержание-пользователей-с-разбивкой-по-устройствам" data-toc-modified-id="Конверсия-и-удержание-пользователей-с-разбивкой-по-устройствам-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Конверсия и удержание пользователей с разбивкой по устройствам</a></span></li><li><span><a href="#Конверсия-и-удержание-пользователей-с-разбивкой-по-каналам-привлечения" data-toc-modified-id="Конверсия-и-удержание-пользователей-с-разбивкой-по-каналам-привлечения-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Конверсия и удержание пользователей с разбивкой по каналам привлечения</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации" data-toc-modified-id="Выводы-и-рекомендации-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы и рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Анализ бизнес-показателей приложения Procrastinate Pro+

# %% [markdown]
# В нашем распоряжении данные развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Цель анализа — разобраться в причинах убытков и помочь компании выйти в плюс.

# %% [markdown]
# Описание данных:
#
# 1) visits_info_short:
# * User Id — уникальный идентификатор пользователя,
# * Region — страна пользователя,
# * Device — тип устройства пользователя,
# * Channel — идентификатор источника перехода,
# * Session Start — дата и время начала сессии,
# * Session End — дата и время окончания сессии.
# 2) orders_info_short:
# * User Id — уникальный идентификатор пользователя,
# * Event Dt — дата и время покупки,
# * Revenue — сумма заказа.
# 3) costs_info_short.csv:
# * dt — дата проведения рекламной кампании,
# * Channel — идентификатор рекламного источника,
# * costs — расходы на эту кампанию.

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
ad_costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# Ознакомимся с исходными данными: выведем несколько строк каждого датасета, посмотрим общую информацию, проверим наличие пропусков и явных дубликатов в данных.

# %%
def data_info(df):
    print(df.head(15))
    print('')
    print(df.info())
    print('')
    print(df.describe())
    print('')
    print('Количество пропусков в датасете:')
    print(df.isna().sum())
    print('')
    print('Количество явных дубликатов в датасете:')
    print(df.duplicated().sum())

# %%
data_info(visits)
# Out:
#          User Id         Region   Device         Channel        Session Start  \
# 0   981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1   278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2   590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3   326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4   349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5    90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6    43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7   185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8   446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9   100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
# 10  589320347244  United States      Mac         YRabbit  2019-05-01 18:39:23
# ...

# %%
data_info(orders)
# Out:
#          User Id             Event Dt  Revenue
# 0   188246423999  2019-05-01 23:09:52   4.9900
# 1   174361394180  2019-05-01 12:24:04   4.9900
# 2   529610067795  2019-05-01 11:34:04   4.9900
# 3   319939546352  2019-05-01 15:34:40   4.9900
# 4   366000285810  2019-05-01 13:59:51   4.9900
# 5   129100331057  2019-05-01 01:56:28   4.9900
# 6   626807144131  2019-05-01 02:39:21   4.9900
# 7   914062168985  2019-05-01 02:02:18   4.9900
# 8   769669137453  2019-05-01 03:39:47   4.9900
# 9   434198630691  2019-05-01 18:16:50   5.9900
# 10  846285993293  2019-05-01 13:14:07   4.9900
# 11   64474110919  2019-05-01 02:21:45   4.9900
# 12   68752468250  2019-05-01 20:25:33   4.9900
# 13  946239768828  2019-05-01 21:11:24   4.9900
# 14  872148430066  2019-05-01 09:18:02   4.9900
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
# ...

# %%
data_info(ad_costs)
# Out:
#             dt   Channel    costs
# 0   2019-05-01  FaceBoom 113.3000
# 1   2019-05-02  FaceBoom  78.1000
# 2   2019-05-03  FaceBoom  85.8000
# 3   2019-05-04  FaceBoom 136.4000
# 4   2019-05-05  FaceBoom 122.1000
# 5   2019-05-06  FaceBoom 118.8000
# 6   2019-05-07  FaceBoom 101.2000
# 7   2019-05-08  FaceBoom 100.1000
# 8   2019-05-09  FaceBoom  93.5000
# 9   2019-05-10  FaceBoom 104.5000
# 10  2019-05-11  FaceBoom 132.0000
# 11  2019-05-12  FaceBoom 100.1000
# 12  2019-05-13  FaceBoom 105.6000
# 13  2019-05-14  FaceBoom  92.4000
# 14  2019-05-15  FaceBoom 100.1000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
#
#           costs
# count 1800.0000
# ...

# %% [markdown]
# Ни пропусков, ни явных дубликатов не обнаружено.

# %% [markdown]
# Приведём названия столбцов во всех трёх датафреймах к нижнему регистру и, где требуется, к snake case.

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns]
ad_costs.columns = ad_costs.columns.str.lower()

# %% [markdown]
# Как можно было заметить выше — столбцы с информацией о дате и времени здесь имеют тип данных `object`. Для корректной работы с ними изменим тип на `datetime`.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
ad_costs['dt'] = pd.to_datetime(ad_costs['dt']).dt.date

# %%
visits.head()
# Out:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           session_end
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# 4 2019-05-01 03:57:40

# %%
orders.head()
# Out:
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52   4.9900
# 1  174361394180 2019-05-01 12:24:04   4.9900
# 2  529610067795 2019-05-01 11:34:04   4.9900
# 3  319939546352 2019-05-01 15:34:40   4.9900
# 4  366000285810 2019-05-01 13:59:51   4.9900

# %%
ad_costs.head()
# Out:
#            dt   channel    costs
# 0  2019-05-01  FaceBoom 113.3000
# 1  2019-05-02  FaceBoom  78.1000
# 2  2019-05-03  FaceBoom  85.8000
# 3  2019-05-04  FaceBoom 136.4000
# 4  2019-05-05  FaceBoom 122.1000

# %% [markdown]
# Посмотрим на уникальные значения в названиях стран, устройств, источников перехода пользователей, возможно там могут быть неявные дубликаты.

# %%
ad_costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %%
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Неявных дубликатов также не обнаруженно.

# %% [markdown]
# **Вывод: исходные данные в хорошем состоянии — пропуски, дубликаты не обнаружены.**

# %% [markdown]
# ## Функции для расчёта и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функции загружены, можно приступать к анализу.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Профили пользователей

# %% [markdown]
# Составим профили пользователей.

# %%
profiles = get_profiles(visits, orders, ad_costs)

# %%
profiles.head(10)
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True            1.0882
# 1  2019-07-09 2019-07-01  False            1.1072
# ...

# %%
min_date = profiles['first_ts'].min()
min_date
# Out:
# Timestamp('2019-05-01 00:00:41')

# %%
max_date = profiles['first_ts'].max()
max_date
# Out:
# Timestamp('2019-10-27 23:59:04')

# %% [markdown]
# Минимальная дата привлечения пользователей — 1 мая 2019 г., максимальная — 27 октября 2019 г.

# %% [markdown]
# ### Распределение пользователей по странам

# %% [markdown]
# Посмотрим, как пользователи были распределены по странам, а также на какую страну приходится больше всего платящих пользователей.

# %%
users_info_by_region = (
    profiles.groupby('region').agg({'user_id': 'nunique'}).reset_index()
    .merge(profiles.query('payer == True').groupby('region').agg({'user_id': 'nunique'}).reset_index(),
           on='region', how='left'))

users_info_by_region.columns = ['region', 'total_users', 'payers']

users_info_by_region['payers_rate'] = users_info_by_region['payers'] / users_info_by_region['total_users'] 
    
users_info_by_region.sort_values(by='payers_rate', ascending=False)
# Out:
#           region  total_users  payers  payers_rate
# 3  United States       100002    6902       0.0690
# 1        Germany        14981     616       0.0411
# 2             UK        17575     700       0.0398
# 0         France        17450     663       0.0380

# %% [markdown]
# Абсолютное большинство всего пользователей пришло к нам из США. Они же и чаще других становились платящими. Пользователи европейских стран по количеству распределены между собой примерно одинаково, наибольшую долю платящих пользователей здесь имеет Германия (несмотря на то, что из нее пришло меньше всего пользователей), а наименьшую — Франция.

# %%
profiles.query('payer == True')['user_id'].count() / profiles['user_id'].count() * 100
# Out:
# 5.920350914617887

# %% [markdown]
# В целом, доля платящих пользователей довольно низкая — около 6%.

# %% [markdown]
# ### Распределение пользователей по устройствам

# %% [markdown]
# Посмотрим, как пользователи распределены по устройствам, а также на какое устройство приходится больше всего платящих пользователей.

# %%
users_info_by_device = (
    profiles.groupby('device').agg({'user_id': 'nunique'}).reset_index()
    .merge(profiles.query('payer == True').groupby('device').agg({'user_id': 'nunique'}).reset_index(),
           on='device', how='left'))

users_info_by_device.columns = ['device', 'total_users', 'payers']

users_info_by_device['payers_rate'] = users_info_by_device['payers'] / users_info_by_device['total_users']

users_info_by_device.sort_values(by='payers_rate', ascending=False)
# Out:
#     device  total_users  payers  payers_rate
# 1      Mac        30042    1912       0.0636
# 3   iPhone        54479    3382       0.0621
# 0  Android        35032    2050       0.0585
# 2       PC        30455    1537       0.0505

# %% [markdown]
# Больше всего среди наших пользователей владельцев iPhone. Между другими устройствами пользователи распределены примерно одинаково. Наибольшая доля платящих пользователей у владельцев Mac, наименьшая — у владельцев PC.

# %%
users_by_region_device = profiles.pivot_table(index=['device', 'region'], values='user_id', aggfunc='nunique', fill_value=0)
users_by_region_device = users_by_region_device.reset_index()
sns.set(rc={"figure.figsize":(12, 8)})
sns.barplot(x='region', y='user_id',
            hue='device', data=users_by_region_device.sort_values(by='user_id', ascending=False), ci= None)
plt.xlabel('Страны')
plt.ylabel('Количество пользователей')
plt.title('Распределение пользователей по устройствам и странам')
# Out:
# Text(0.5, 1.0, 'Распределение пользователей по устройствам и странам')

# %% [markdown]
# В США наиболее популярна продукция Apple: iPhone и Mac. Предпочтения по устройствам у пользователей из европейских стран очень похожи между собой, топ их устройств абсолютно идентичный: сначала PC и Android, и только потом iPhone и Mac.

# %% [markdown]
# ### Распределение пользователей по каналам привлечения пользователей

# %% [markdown]
# Посмотрим, как пользователи распределены по каналам привлечения, а также на какой канал приходится больше всего платящих пользователей.

# %%
users_info_by_channel = (
    profiles.groupby('channel').agg({'user_id': 'nunique'}).reset_index()
    .merge(profiles.query('payer == True').groupby('channel').agg({'user_id': 'nunique'}).reset_index(),
           on='channel', how='left'))

users_info_by_channel.columns = ['channel', 'total_users', 'payers']

users_info_by_channel['payers_rate'] = users_info_by_channel['payers'] / users_info_by_channel['total_users']

users_info_by_channel.sort_values(by='payers_rate', ascending=False)
# Out:
#                channel  total_users  payers  payers_rate
# 1             FaceBoom        29144    3557       0.1220
# 0           AdNonSense         3880     440       0.1134
# 9       lambdaMediaAds         2149     225       0.1047
# 6               TipTop        19561    1878       0.0960
# 5       RocketSuperAds         4448     352       0.0791
# 7       WahooNetBanner         8553     453       0.0530
# 8              YRabbit         4312     165       0.0383
# 3         MediaTornado         4364     156       0.0357
# 2              LeapBob         8553     262       0.0306
# 4   OppleCreativeMedia         8605     233       0.0271
# 10             organic        56439    1160       0.0206

# %% [markdown]
# Несмотря на то, что больше всего пользователей пришли в приложение органически (т.е. естественным образом нашли сайт в поисковой выдаче, а не попали на сайт через рекламу), доля платящих пользователей среди них самая низкая. На втором месте по количеству привлеченных пользователей — `FaceBoom`. Через него также пришла наибольшая доля платящих пользователей.

# %% [markdown]
# Проверим также как пользователи разных стран распределены по каналам привлечения.

# %%
users_by_region_channel = profiles.pivot_table(index=['channel',
                                             'region'], values='user_id', aggfunc='nunique', fill_value=0)

users_by_region_channel = users_by_region_channel.reset_index()
sns.set(rc={"figure.figsize":(16, 8)})
sns.barplot(x='channel', y='user_id',
            hue='region', data=users_by_region_channel.sort_values(by='user_id', ascending=False), ci= None)
plt.xlabel('Каналы привлечения')
plt.ylabel('Количество пользователей')
plt.title('Распределение пользователей по каналам привлечения и странам')
# Out:
# Text(0.5, 1.0, 'Распределение пользователей по каналам привлечения и странам')

# %% [markdown]
# На графике можно заметить, что рекламные каналы географически делятся строго на американские (5 шт.) и европейские (5 шт.). Среди американских каналов наибольшую долю платящих имеет как раз `FaceBoom`, среди европейских — `AdNonSense`.

# %% [markdown]
# **Вывод: в первую очередь пользователи делятся по географическому признаку на американских и европейских. Это влияет на то, какими устройствами они предпочитают пользоваться, через какие каналы привлечения попадают в приложение (кроме органических переходов). Нашим приложением чаще всего пользуются пользователи из США (они же имеют и наибольшую долю платящих по сравнению с другими странами), где платящие пользователи в основном: используют продукцию `Apple`, приходят к нам из канала привлечения `FaceBoom`.**

# %% [markdown]
# ## Маркетинг

# %%
ad_costs['costs'].sum()
# Out:
# 105497.30000000002

# %% [markdown]
# Общая сумма расходов на маркетинг за всё время наблюдений составила — около 105 497 долларов.

# %% [markdown]
# Посмотрим, как траты распределены по рекламным источникам.

# %%
ad_costs.groupby('channel').agg({'costs': 'sum'}).reset_index().sort_values(by='costs', ascending=False)
# Out:
#               channel      costs
# 6              TipTop 54751.3000
# 1            FaceBoom 32445.6000
# 7      WahooNetBanner  5151.0000
# 0          AdNonSense  3911.2500
# 4  OppleCreativeMedia  2151.2500
# 5      RocketSuperAds  1833.0000
# 2             LeapBob  1797.6000
# 9      lambdaMediaAds  1557.6000
# 3        MediaTornado   954.4800
# 8             YRabbit   944.2200

# %% [markdown]
# Больше всего денег было потрачено на рекламу в `TipTop` — 54 751,3 долларов. Меньше всего затрат на рекламу в `YRabbit` — всего 944,2 доллара.

# %% [markdown]
# Посмотрим, как расходы на каждый источник изменялись во времени: по неделям и месяцам.

# %%
costs_by_week = ad_costs.copy() 
costs_by_week['week'] = pd.to_datetime(costs_by_week['dt']).dt.isocalendar().week
costs_by_week = costs_by_week.groupby(['channel', 'week']).agg({'costs': 'sum'}).reset_index()
plt.figure(figsize=(14, 8))
sns.lineplot(data=costs_by_week, x='week', y='costs', hue='channel')
plt.xlabel('Номер недели')
plt.ylabel('Суммарные расходы')
plt.title('Изменения расходов на рекламу по неделям')
plt.show()

# %%
costs_by_month = ad_costs.copy() 
costs_by_month['month'] = pd.to_datetime(costs_by_month['dt']).dt.month
costs_by_month = costs_by_month.groupby(['channel', 'month']).agg({'costs': 'sum'}).reset_index()
plt.figure(figsize=(14, 8))
sns.lineplot(data=costs_by_month, x='month', y='costs', hue='channel')
plt.xlabel('Номер месяца')
plt.ylabel('Суммарные расходы')
plt.title('Изменения расходов на рекламу по месяцам')
plt.show()

# %% [markdown]
# На графиках выделяются два канала — `TipTop` и `FaceBoom` — в них вложено больше всего денег. Для остальных каналов привлечения картина по количеству вложенных денег примерно одинаково низкая.
#
# На графике изменения расходов по неделям видно, что рост и снижение расходов у этих двух каналов пришлись по большей части на одни и те же недели, а значит, рекламные кампании у них проводились скорее всего в одно и то же время.
#
# На динамике расходов по месяцам мы видим как сильно росли денежные вложения в `TipTop`: за 6 месяцев расходы здесь выросли в 4 раза!

# %% [markdown]
# Проверим, сколько в среднем стоило привлечение одного пользователя из каждого источника.

# %%
(profiles.query('channel != "organic"').groupby('channel')
                                       .agg({'acquisition_cost': 'mean'})
                                       .reset_index().sort_values(by='acquisition_cost', ascending=False))
# Out:
#               channel  acquisition_cost
# 6              TipTop            2.7990
# 1            FaceBoom            1.1133
# 0          AdNonSense            1.0081
# 9      lambdaMediaAds            0.7248
# 7      WahooNetBanner            0.6022
# 5      RocketSuperAds            0.4121
# 4  OppleCreativeMedia            0.2500
# 8             YRabbit            0.2190
# 3        MediaTornado            0.2187
# 2             LeapBob            0.2102

# %% [markdown]
# Дороже всего стоило привлечение пользователей из `TipTop` — в среднем около 2.8 долларов за пользователя. Дешевле всего — из `LeapBob` (0.21 доллара).

# %% [markdown]
# **Вывод: суммарные затраты на рекламу составили 105 497 долларов, более половины из которых были потрачены на `TipTop`. При этом, привлечение пользователей через это канал было самым дорогим — 2.8 доллара за 1 пользователя.
# На втором месте по суммарным затратам на рекламу — `FaceBoom` (32445.6 долларов). Средние затраты на привлечение одного пользователя здесь составили — 1.1 доллара (т.е. в 2,5 раза меньше чем через `TipTop`).**

# %% [markdown]
# ## Окупаемость рекламы

# %% [markdown]
# Проанализируем окупаемость рекламы с помощью графиков LTV, ROI и CAC. Органических пользователей включать в анализ не будем, так как они были привлечены без затрат на рекламу. Момент анализа — 27 октября 2019 г., горизонт анализа — 14 дней.

# %% [markdown]
# ### Общая окупаемость рекламы

# %% [markdown]
# Для оценки общей окупаемости рекламы построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
observation_date = max_date  # момент анализа
horizon_days = 14  # горизонт анализа

# %%
profiles_from_ads = profiles.query('channel != "organic"')

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_from_ads, orders, observation_date, horizon_days)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Из графиков можно сделать следующие выводы:
# * Реклама не окупается. ROI к концу второй недели составляет около 80%.
# * LTV достаточно стабилен. Значит, дело не в ухудшении качества пользователей;
# * CAC постоянно растёт, причём неравномерно — рекламные кампании проводятся регулярно, с практически постоянным увеличением бюджета. Это и является причиной неокупаемости рекламы: расходы обгоняют доходы.

# %% [markdown]
# ### Конверсия и удержание пользователей

# %% [markdown]
# Рассмотрим графики конверсии и удержания пользователей в общем и с разбивкой по странам, устройствам, каналам привлечения.

# %% [markdown]
# #### Конверсия и удержание пользователей в общем

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_from_ads, orders, observation_date, horizon_days)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи на протяжении всего лайфтайма конвертируются стабильно, но не очень активно — на конец второй недели конверсия достигает 8%. Лучшие показатели конверсии на 14-й день были у пользователей, привлеченных в середине июня, середине августа и начале сентября. Худшие — у пользователей, привлеченных в середине мая, конце июля и конце августа.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_from_ads, visits, observation_date, horizon_days)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Платящие пользователи удерживаются неплохо, их количество за первые 14 дней плавно снижается с 38% до 11%. Удержание неплатящих пользователей низкое: на первый день оно составляет около 17%, на 4 день — около 4%, на 8 день — около 2%, после 12 дня — практически 0.

# %% [markdown]
# #### Конверсия и удержание пользователей с разбивкой по странам

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_from_ads, orders, observation_date, horizon_days, dimensions=['region'])

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия пользователей из США в 2 раза выше чем у пользователей из Европы. К концу второй недели пользователи из США также конвертировались лучше пользователей из Европы (кроме тех, кто был привлечен в мае).

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_from_ads, visits, observation_date, horizon_days, dimensions=['region'])

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Неожиданно, но несмотря на самую высокую конверсию, платящие пользователи из США стабильно хуже удерживаются относительно платящих пользователей из Европы (примерно в 1,5 раза). Что касается неплатящих пользователей, то здесь дела обстоят примерно одинаково плохо у всех.
#
# Удержание пользователей из европейских стран на графике выглядит менее стабильно по сравнению с американскими скорее всего за счет разницы в количестве наблюдений.

# %% [markdown]
# #### Конверсия и удержание пользователей с разбивкой по устройствам

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_from_ads, orders, observation_date, horizon_days, dimensions=['device'])

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Лучшую конверсию показывают устройства `Apple` что логично, т.к. мы знаем что ими преимущественно пользуются в США. Хуже всего конвертируются пользователи `PC`.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_from_ads, visits, observation_date, horizon_days, dimensions=['device'])

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Несмотря на лучшую конверсию, платящие пользователи устройств `Apple` удерживаются чуть хуже своих конкурентов. Лучшее удержание здесь показывает PC.
#
# С неплатящими пользователями картина печальная — удержание их на 14-й практически нулевое.

# %% [markdown]
# #### Конверсия и удержание пользователей с разбивкой по каналам привлечения

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_from_ads, orders, observation_date, horizon_days, dimensions=['channel'])

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Лучшую конверсию показывают каналы — `FaceBoom`, `AdNonSense` и `lambdaMediaAds`. Хуже всего конверсия через — `OppleCreativeMedia`, `LeapBob` и `MediaTornado`.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_from_ads, visits, observation_date, horizon_days, dimensions=['channel'])

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Интересно, что из платящих пользователей хуже всего удерживаются те, что пришли через `AdNonSense` и `FaceBoom` (у этих каналов наилучшая конверсия). Одно из возможных объяснений этому — пользователи, привлеченные через эти каналы, при осуществлении платежа в нашем приложении, могут получать что-то в другом приложении/сервисе и, таким образом, изначально не иметь высокой мотивации пользоваться нашим сервисом, не быть нашей целевой аудиторией.
#
# С неплатящими пользователями дела обстоят примерно одинаково плохо у всех.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %% [markdown]
# Построим и проанализируем графики LTV и ROI, а также графики динамики LTV, CAC и ROI с разбивкой по устройствам.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_from_ads, orders, observation_date, horizon_days, dimensions=['device'])

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Глядя на графики можно сделать следующие выводы:
# * LTV для всех устройств стабилен, немного выделяется `PC` — его значения чуть ниже, чем у остальных;
# * У `Mac`, `iPhone` и `Android` реклама не окупается совсем. А у `PC` дела чуть лучше — для их пользователей реклама начинает окупаться только после одиннадцатого дня;
# * По стоимости привлечения пользователей ожидаемо лидируют `Mac` и `iPhone`.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %% [markdown]
# Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI  с разбивкой по странам.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_from_ads, orders, observation_date, horizon_days, dimensions=['region'])

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# На графиках видно, что:
# * LTV для всех стран стабилен и самый высокий он у пользователей из США;
# * Несмотря на то, что почти весь рекламный бюджет уходит на пользователей из США, реклама для них совершенно не окупается — на протяжении всего лайфтайма ROI здесь ни разу не приблизился к положительному.
# * Расходы на рекламу для пользователей из Европы по сравнению с США стабильно низкие. Реклама для них начинает окупаться на 4-6 день.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI с разбивкой по рекламным каналам.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_from_ads, orders, observation_date, horizon_days, dimensions=['channel'])

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Из графиков видно:
# * LTV у всех стабилен, чуть лучшие себя показывают каналы `lambdaMediaAds` и `TipTop`;
# * CAC был стабильно низкий у всех, кроме `TipTop` — за полгода расходы на рекламу здесь выросли в 2,5 раза;
# * Несмотря на все денежные вливания, реклама в `TipTop` не окупилась совсем (как и у `FaceBoom`, `AdNonSense`). У остальных каналов реклама начала окупаться на 2-6 день.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Негативное влияние на окупаемость рекламы оказали невероятные траты на рекламу в американском канале `TipTop` — несмотря на постоянное увеличение бюджета, из данного канала не пришло достаточное количество платящих пользователей чтобы затраты на рекламу в нем смогли окупиться.
#
# Второй по количеству затрат — американский канал `FaceBoom`. Вложения в него также совершенно не окупились: пользователи конвертировались относительно неплохо, но очень быстро уходили из приложения. Аналогичная ситуация и с европейским каналом `AdNonSense`.
#
# Затраты на остальные каналы окупались на 2-6 день "жизни" пользователей.

# %% [markdown]
# ## Выводы и рекомендации

# %% [markdown]
# Исходные данные были представлены в виде трёх датафреймов — лога сервера с информацией о посещениях сайта пользователями, информации о их заказах, информации о расходах на рекламу. Данные были в хорошем состоянии — на этапе предобработки данных во всех трёх датафреймах не были обнаружены ни пропуски, ни дубликаты.
#
# Во время исследовательского анализа были определены группы, имеющие наибольшие доли платящих пользователей. Это:
# * пользователи из США — всего их 100002, при этом 6902 из них платящие;
# * пользуются `Mac` и `iPhone` — доли платящих 0,063 и 0,062 соответсвенно;
# * приходят из каналов привлечения `FaceBoom`, `AdNonSense` и `lambdaMediaAds` (суммарно имеют около трети от всех платящих пользователей).
#
# Общая сумма расходов на маркетинг за всё время наблюдений составила — около 105 497 долларов. Половина этих денег была вложена в канал `TipTop` — 54 751,3 долларов.
#
# Во время оценки окупаемости рекламы стало понятно, что это было неверное решение — несмотря на постоянно возрастающие денежные вложения в данный канал, реклама здесь совершенно не окупилась. Также, не окупились и затраты на привлечение пользователей через `FaceBoom` и `AdNonSense` — их пользователи конвертировались относительно неплохо, но очень быстро уходили из приложения. Одно из возможных объяснений этому — пользователи, привлеченные через эти каналы, при осуществлении платежа в нашем приложении, могли получать что-то в другом сервисе и, таким образом, изначально не иметь высокой мотивации пользоваться нашим сервисом/не быть нашей целевой аудиторией.
#
# *Рекомендации*
#
# Бюджет стоит перенаправить в пользу европейского канала `lambdaMediaAds` и американского `RocketSuperAds`, т.к.:
# * у них хорошие конверсия и удержание;
# * стабильно низкая стоимость привлечения пользователей — в среднем 0,73 доллара за пользователя для `lambdaMediaAds` и 0,4 доллара за пользователя для `RocketSuperAds`;
# * реклама в них начинает окупаться примерно со второго дня.
